# %% [markdown]
#                                Assignment on Python for Data Science
#
#
# Do the following operation on Iris dataset:
# 1. Read the dataset to python environment.

# %%
import pandas as pd
file_path = '/content/iris.xls'
iris_df = pd.read_excel(file_path)
iris_df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
#Displaying the column names
iris_df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
iris_df.mean()
# Out:
# <ipython-input-43-d84e913cdd1d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_df.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
iris_df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
#The following Bar graph display the number of observations of each flower
iris_df.Classification.value_counts().plot(kind="bar",color="g")
plt.xticks(rotation=50)
plt.title("Number of Observations of Each Kind of Flowers")
plt.xlabel("Flower Kind")
plt.ylabel("Sample Size")
plt.show()

# %%
#The following codes give a scatter plot of
#sepal length vs Sepal width for each type of flower
iset=iris_df[iris_df.Classification=="Iris-setosa"]


iver=iris_df[iris_df.Classification=="Iris-versicolor"]


ivir=iris_df[iris_df.Classification=="Iris-virginica"]


plt.scatter(iset.SL,iset.SW,color="r",label="iris setosa")
plt.scatter(iver.SL,iver.SW,color="b",label="iris versicolor")
plt.scatter(ivir.SL,ivir.SW,color="m",label="iris virginica")
plt.legend()
plt.show()

# %%
# Create a boxplot of the 'sepal_length' feature
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

sns.boxplot(x='species', y='sepal_length', data=iris)

# Show the plot
plt.show()

# %%
# Create a violinplot of the 'petal_width' feature
sns.violinplot(x='species', y='petal_width', data=iris)

# Show the plot
plt.show()
